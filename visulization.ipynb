# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os 
import scienceplots

# %%
# eigen0 = np.load('results/synthetic/perturbed_with_noise/10pm0/MNGD/Decide_2024_11_06_12_07_29/preserved_eigens2194.npy')
# eigen1 = np.load('results/synthetic/perturbed_with_noise/10pm1/MNGD/Decide_2024_11_04_17_35_32/preserved_eigens2210.npy')
# eigen2 = np.load('results/synthetic/perturbed_with_noise/10pm2/MNGD/Decide_2024_11_05_22_52_28/preserved_eigens2204.npy')
eigen0 = np.load('results/synthetic/perturbed_with_condition/u0/MNGD/Decide_2024_11_06_12_08_11/preserved_eigens2192.npy')
eigen1 = np.load('results/synthetic/perturbed_with_condition/u1/MNGD/Decide_2024_11_04_17_35_52/preserved_eigens2196.npy')
eigen2 = np.load('results/synthetic/perturbed_with_condition/u2/MNGD/Decide_2024_11_05_22_52_01/preserved_eigens2204.npy')

# %%
# plt.plot(np.sum(eigen0, axis=1), label='noise 0')
# plt.plot(np.sum(eigen1, axis=1), label='noise 1')
# plt.plot(np.sum(eigen2, axis=1), label='noise 2')
plt.plot(np.sum(eigen0, axis=0), label='noise 0')
plt.plot(np.sum(eigen1, axis=0), label='noise 1')
plt.plot(np.sum(eigen2, axis=0), label='noise 2')
plt.legend()
plt.show()
